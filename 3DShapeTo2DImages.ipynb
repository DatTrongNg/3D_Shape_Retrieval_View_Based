# %%
# pip install -U trimesh[easy]

# %%
# pip install pyglet==1.5.11

# %%
import numpy as np
import pyglet
import trimesh
import os
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import gzip
import io
import matplotlib.pyplot as plt
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] The specified procedure could not be found
#   warn(f"Failed to load image Python extension: {e}")

# %%
class McGillDataset(Dataset):
    def __init__(self, root_dir: str, file_type: str = 'ply', transform=None):
        """
        Custom dataset for McGill dataset.

        Parameters:
        - root_dir (str): Root directory of the dataset.
        - file_type (str, optional): Type of file to load data from. Defaults to 'ply'.
        - transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.file_type = file_type
        self.transform = transform

        # List all the categories (subdirectories) in the root directory
        self.categories = os.listdir(root_dir)

        # Create a dictionary to map category names to their respective subdirectories
        self.category_paths = {category: os.path.join(root_dir, category) for category in self.categories}

        self.all_data_paths = self.get_all_data_paths()

    def __len__(self):
        """
        Returns the total number of samples in the dataset.
        """
        return len(self.all_data_paths)

    def __getitem__(self, idx):
        """
        Returns a sample from the dataset.

        Parameters:
        - idx (int): Index of the sample.

        Returns:
        - sample (dict): A dictionary containing 'data' (3D mesh) and 'label' (category name).
        """
        # Load the data (3D mesh) using the appropriate method
        data_path = self.all_data_paths[idx]
        category = self.get_category_from_path(data_path)

        if self.file_type == 'Im':
            with gzip.open(data_path, 'rb') as f:
                data = Image.open(io.BytesIO(f.read()))
        elif self.file_type == 'Ply':
            if data_path.endswith('.gz'):
                with gzip.open(data_path, 'rb') as f:
                    file_extension = os.path.splitext(data_path[:-3])[1]
                    data = trimesh.load(file_obj=io.BytesIO(f.read()), file_type=file_extension, process=False)
            else:
                file_extension = os.path.splitext(data_path)[1]
                data = trimesh.load(data_path, file_type=file_extension, process=False)

        # Apply the optional transform
        if self.transform:
            data = self.transform(data)

        # Prepare the sample dictionary
        sample = {'data': data, 'label': category}

        return sample

    def get_category_from_path(self, data_path):
        """
        Extract category name from the data path.

        Parameters:
        - data_path (str): Full path to the data file.

        Returns:
        - category (str): Category name.
        """
        # Extract category name from the path
        category = os.path.basename(os.path.dirname(os.path.dirname(data_path)))
        return category


    def get_all_data_paths(self):
        """
        Return a list of all data paths in the dataset.
        """
        all_paths = []
        for category in self.categories:
            category_path = self.category_paths[category]
            data_paths = os.listdir(os.path.join(category_path, f'{category}{self.file_type}'))
            full_paths = [os.path.join(category_path, f'{category}{self.file_type}', data_name) for data_name in data_paths]
            all_paths.extend(full_paths)
        return all_paths

    def get_mesh(self, idx):
        """
        Return the 3D mesh.

        Parameters:
        - idx (int): Index of the sample.
        """
        return self.__getitem__(idx)['data']

# %%
root_dir = './articulated/'
# Create an instance of the McGillDataset class for Ply files
mcgill_dataset_ply = McGillDataset(root_dir, file_type='Ply')

# %%
print(len(mcgill_dataset_ply))
mcgill_dataset_ply.all_data_paths
# Out:
# 255
# ['./articulated/ants\\antsPly\\1.ply.gz',
#  './articulated/ants\\antsPly\\11.ply.gz',
#  './articulated/ants\\antsPly\\12.ply.gz',
#  './articulated/ants\\antsPly\\13.ply.gz',
#  './articulated/ants\\antsPly\\14.ply.gz',
#  './articulated/ants\\antsPly\\16.ply.gz',
#  './articulated/ants\\antsPly\\17.ply.gz',
#  './articulated/ants\\antsPly\\18.ply.gz',
#  './articulated/ants\\antsPly\\19.ply.gz',
#  './articulated/ants\\antsPly\\2.ply.gz',
#  './articulated/ants\\antsPly\\20.ply.gz',
#  './articulated/ants\\antsPly\\21.ply.gz',
#  './articulated/ants\\antsPly\\22.ply.gz',
#  './articulated/ants\\antsPly\\23.ply.gz',
#  './articulated/ants\\antsPly\\26.ply.gz',
#  './articulated/ants\\antsPly\\27.ply.gz',
#  './articulated/ants\\antsPly\\28.ply.gz',
#  './articulated/ants\\antsPly\\29.ply.gz',
#  './articulated/ants\\antsPly\\3.ply.gz',
#  './articulated/ants\\antsPly\\30.ply.gz',
#  './articulated/ants\\antsPly\\31.ply.gz',
#  './articulated/ants\\antsPly\\32.ply.gz',
#  './articulated/ants\\antsPly\\33.ply.gz',
#  './articulated/ants\\antsPly\\34.ply.gz',
#  './articulated/ants\\antsPly\\4.ply.gz',
#  './articulated/ants\\antsPly\\5.ply.gz',
#  './articulated/ants\\antsPly\\6.ply.gz',
#  './articulated/ants\\antsPly\\7.ply.gz',
#  './articulated/ants\\antsPly\\8.ply.gz',
#  './articulated/ants\\antsPly\\9.ply.gz',
#  './articulated/crabs\\crabsPly\\1.ply.gz',
#  './articulated/crabs\\crabsPly\\10.ply.gz',
#  './articulated/crabs\\crabsPly\\11.ply.gz',
#  './articulated/crabs\\crabsPly\\12.ply.gz',
#  './articulated/crabs\\crabsPly\\13.ply.gz',
#  './articulated/crabs\\crabsPly\\14.ply.gz',
#  './articulated/crabs\\crabsPly\\15.ply.gz',
#  './articulated/crabs\\crabsPly\\16.ply.gz',
#  './articulated/crabs\\crabsPly\\17.ply.gz',
#  './articulated/crabs\\crabsPly\\18.ply.gz',
#  './articulated/crabs\\crabsPly\\19.ply.gz',
#  './articulated/crabs\\crabsPly\\2.ply.gz',
#  './articulated/crabs\\crabsPly\\20.ply.gz',
#  './articulated/crabs\\crabsPly\\21.ply.gz',
#  './articulated/crabs\\crabsPly\\22.ply.gz',
#  './articulated/crabs\\crabsPly\\23.ply.gz',
#  './articulated/crabs\\crabsPly\\24.ply.gz',
#  './articulated/crabs\\crabsPly\\25.ply.gz',
#  './articulated/crabs\\crabsPly\\26.ply.gz',
#  './articulated/crabs\\crabsPly\\27.ply.gz',
#  './articulated/crabs\\crabsPly\\28.ply.gz',
#  './articulated/crabs\\crabsPly\\29.ply.gz',
#  './articulated/crabs\\crabsPly\\3.ply.gz',
#  './articulated/crabs\\crabsPly\\30.ply.gz',
#  './articulated/crabs\\crabsPly\\4.ply.gz',
#  './articulated/crabs\\crabsPly\\5.ply.gz',
#  './articulated/crabs\\crabsPly\\6.ply.gz',
#  './articulated/crabs\\crabsPly\\7.ply.gz',
#  './articulated/crabs\\crabsPly\\8.ply.gz',
#  './articulated/crabs\\crabsPly\\9.ply.gz',
#  './articulated/hands\\handsPly\\b1.ply.gz',
#  './articulated/hands\\handsPly\\b10.ply.gz',
#  './articulated/hands\\handsPly\\b11.ply.gz',
#  './articulated/hands\\handsPly\\b12.ply.gz',
#  './articulated/hands\\handsPly\\b13.ply.gz',
#  './articulated/hands\\handsPly\\b14.ply.gz',
#  './articulated/hands\\handsPly\\b15.ply.gz',
#  './articulated/hands\\handsPly\\b16.ply.gz',
#  './articulated/hands\\handsPly\\b17.ply.gz',
#  './articulated/hands\\handsPly\\b18.ply.gz',
#  './articulated/hands\\handsPly\\b19.ply.gz',
#  './articulated/hands\\handsPly\\b2.ply.gz',
#  './articulated/hands\\handsPly\\b20.ply.gz',
#  './articulated/hands\\handsPly\\b3.ply.gz',
#  './articulated/hands\\handsPly\\b4.ply.gz',
#  './articulated/hands\\handsPly\\b5.ply.gz',
#  './articulated/hands\\handsPly\\b6.ply.gz',
#  './articulated/hands\\handsPly\\b7.ply.gz',
#  './articulated/hands\\handsPly\\b8.ply.gz',
#  './articulated/hands\\handsPly\\b9.ply.gz',
#  './articulated/humans\\humansPly\\b1.ply',
#  './articulated/humans\\humansPly\\b10.ply',
#  './articulated/humans\\humansPly\\b11.ply',
#  './articulated/humans\\humansPly\\b12.ply',
#  './articulated/humans\\humansPly\\b13.ply',
#  './articulated/humans\\humansPly\\b14.ply',
#  './articulated/humans\\humansPly\\b15.ply',
#  './articulated/humans\\humansPly\\b16.ply',
#  './articulated/humans\\humansPly\\b17.ply',
#  './articulated/humans\\humansPly\\b18.ply',
#  './articulated/humans\\humansPly\\b19.ply',
#  './articulated/humans\\humansPly\\b2.ply',
#  './articulated/humans\\humansPly\\b20.ply',
#  './articulated/humans\\humansPly\\b21.ply',
#  './articulated/humans\\humansPly\\b22.ply',
#  './articulated/humans\\humansPly\\b23.ply',
#  './articulated/humans\\humansPly\\b24.ply',
#  './articulated/humans\\humansPly\\b25.ply',
#  './articulated/humans\\humansPly\\b26.ply',
#  './articulated/humans\\humansPly\\b28.ply',
#  './articulated/humans\\humansPly\\b29.ply',
#  './articulated/humans\\humansPly\\b3.ply',
#  './articulated/humans\\humansPly\\b30.ply',
#  './articulated/humans\\humansPly\\b4.ply',
#  './articulated/humans\\humansPly\\b5.ply',
#  './articulated/humans\\humansPly\\b6.ply',
#  './articulated/humans\\humansPly\\b7.ply',
#  './articulated/humans\\humansPly\\b8.ply',
#  './articulated/humans\\humansPly\\b9.ply',
#  './articulated/octopus\\octopusPly\\1.ply.gz',
#  './articulated/octopus\\octopusPly\\10.ply.gz',
#  './articulated/octopus\\octopusPly\\11.ply.gz',
#  './articulated/octopus\\octopusPly\\12.ply.gz',
#  './articulated/octopus\\octopusPly\\13.ply.gz',
#  './articulated/octopus\\octopusPly\\14.ply.gz',
#  './articulated/octopus\\octopusPly\\17.ply.gz',
#  './articulated/octopus\\octopusPly\\18.ply.gz',
#  './articulated/octopus\\octopusPly\\25.ply.gz',
#  './articulated/octopus\\octopusPly\\26.ply.gz',
#  './articulated/octopus\\octopusPly\\27.ply.gz',
#  './articulated/octopus\\octopusPly\\28.ply.gz',
#  './articulated/octopus\\octopusPly\\29.ply.gz',
#  './articulated/octopus\\octopusPly\\3.ply.gz',
#  './articulated/octopus\\octopusPly\\30.ply.gz',
#  './articulated/octopus\\octopusPly\\4.ply.gz',
#  './articulated/octopus\\octopusPly\\5.ply.gz',
#  './articulated/octopus\\octopusPly\\51.ply.gz',
#  './articulated/octopus\\octopusPly\\62.ply.gz',
#  './articulated/octopus\\octopusPly\\63.ply.gz',
#  './articulated/octopus\\octopusPly\\67.ply.gz',
#  './articulated/octopus\\octopusPly\\69.ply.gz',
#  './articulated/octopus\\octopusPly\\7.ply.gz',
#  './articulated/octopus\\octopusPly\\8.ply.gz',
#  './articulated/octopus\\octopusPly\\9.ply.gz',
#  './articulated/pliers\\pliersPly\\b1.ply.gz',
#  './articulated/pliers\\pliersPly\\b10.ply.gz',
#  './articulated/pliers\\pliersPly\\b11.ply.gz',
#  './articulated/pliers\\pliersPly\\b12.ply.gz',
#  './articulated/pliers\\pliersPly\\b13.ply.gz',
#  './articulated/pliers\\pliersPly\\b14.ply.gz',
#  './articulated/pliers\\pliersPly\\b15.ply.gz',
#  './articulated/pliers\\pliersPly\\b16.ply.gz',
#  './articulated/pliers\\pliersPly\\b17.ply.gz',
#  './articulated/pliers\\pliersPly\\b18.ply.gz',
#  './articulated/pliers\\pliersPly\\b19.ply.gz',
#  './articulated/pliers\\pliersPly\\b2.ply.gz',
#  './articulated/pliers\\pliersPly\\b20.ply.gz',
#  './articulated/pliers\\pliersPly\\b3.ply.gz',
#  './articulated/pliers\\pliersPly\\b4.ply.gz',
#  './articulated/pliers\\pliersPly\\b5.ply.gz',
#  './articulated/pliers\\pliersPly\\b6.ply.gz',
#  './articulated/pliers\\pliersPly\\b7.ply.gz',
#  './articulated/pliers\\pliersPly\\b8.ply.gz',
#  './articulated/pliers\\pliersPly\\b9.ply.gz',
#  './articulated/snakes\\snakesPly\\1.ply.gz',
#  './articulated/snakes\\snakesPly\\10.ply.gz',
#  './articulated/snakes\\snakesPly\\11.ply.gz',
#  './articulated/snakes\\snakesPly\\12.ply.gz',
#  './articulated/snakes\\snakesPly\\13.ply.gz',
#  './articulated/snakes\\snakesPly\\14.ply.gz',
#  './articulated/snakes\\snakesPly\\15.ply.gz',
#  './articulated/snakes\\snakesPly\\16.ply.gz',
#  './articulated/snakes\\snakesPly\\17.ply.gz',
#  './articulated/snakes\\snakesPly\\18.ply.gz',
#  './articulated/snakes\\snakesPly\\19.ply.gz',
#  './articulated/snakes\\snakesPly\\2.ply.gz',
#  './articulated/snakes\\snakesPly\\20.ply.gz',
#  './articulated/snakes\\snakesPly\\21.ply.gz',
#  './articulated/snakes\\snakesPly\\22.ply.gz',
#  './articulated/snakes\\snakesPly\\23.ply.gz',
#  './articulated/snakes\\snakesPly\\24.ply.gz',
#  './articulated/snakes\\snakesPly\\25.ply.gz',
#  './articulated/snakes\\snakesPly\\27.ply.gz',
#  './articulated/snakes\\snakesPly\\30.ply.gz',
#  './articulated/snakes\\snakesPly\\31.ply.gz',
#  './articulated/snakes\\snakesPly\\4.ply.gz',
#  './articulated/snakes\\snakesPly\\5.ply.gz',
#  './articulated/snakes\\snakesPly\\7.ply.gz',
#  './articulated/snakes\\snakesPly\\8.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b1.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b10.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b11.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b12.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b13.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b14.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b15.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b16.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b17.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b18.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b19.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b2.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b20.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b21.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b22.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b23.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b24.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b25.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b3.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b4.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b5.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b6.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b7.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b8.ply.gz',
#  './articulated/spectacles\\spectaclesPly\\b9.ply.gz',
#  './articulated/spiders\\spidersPly\\1.ply.gz',
#  './articulated/spiders\\spidersPly\\10.ply.gz',
#  './articulated/spiders\\spidersPly\\11.ply.gz',
#  './articulated/spiders\\spidersPly\\12.ply.gz',
#  './articulated/spiders\\spidersPly\\13.ply.gz',
#  './articulated/spiders\\spidersPly\\14.ply.gz',
#  './articulated/spiders\\spidersPly\\15.ply.gz',
#  './articulated/spiders\\spidersPly\\16.ply.gz',
#  './articulated/spiders\\spidersPly\\17.ply.gz',
#  './articulated/spiders\\spidersPly\\18.ply.gz',
#  './articulated/spiders\\spidersPly\\19.ply.gz',
#  './articulated/spiders\\spidersPly\\2.ply.gz',
#  './articulated/spiders\\spidersPly\\20.ply.gz',
#  './articulated/spiders\\spidersPly\\21.ply.gz',
#  './articulated/spiders\\spidersPly\\22.ply.gz',
#  './articulated/spiders\\spidersPly\\23.ply.gz',
#  './articulated/spiders\\spidersPly\\24.ply.gz',
#  './articulated/spiders\\spidersPly\\25.ply.gz',
#  './articulated/spiders\\spidersPly\\26.ply.gz',
#  './articulated/spiders\\spidersPly\\27.ply.gz',
#  './articulated/spiders\\spidersPly\\28.ply.gz',
#  './articulated/spiders\\spidersPly\\29.ply.gz',
#  './articulated/spiders\\spidersPly\\3.ply.gz',
#  './articulated/spiders\\spidersPly\\30.ply.gz',
#  './articulated/spiders\\spidersPly\\31.ply.gz',
#  './articulated/spiders\\spidersPly\\4.ply.gz',
#  './articulated/spiders\\spidersPly\\5.ply.gz',
#  './articulated/spiders\\spidersPly\\6.ply.gz',
#  './articulated/spiders\\spidersPly\\7.ply.gz',
#  './articulated/spiders\\spidersPly\\8.ply.gz',
#  './articulated/spiders\\spidersPly\\9.ply.gz',
#  './articulated/teddy\\teddyPly\\b1.ply.gz',
#  './articulated/teddy\\teddyPly\\b10.ply.gz',
#  './articulated/teddy\\teddyPly\\b11.ply.gz',
#  './articulated/teddy\\teddyPly\\b12.ply.gz',
#  './articulated/teddy\\teddyPly\\b13.ply.gz',
#  './articulated/teddy\\teddyPly\\b14.ply.gz',
#  './articulated/teddy\\teddyPly\\b15.ply.gz',
#  './articulated/teddy\\teddyPly\\b16.ply.gz',
#  './articulated/teddy\\teddyPly\\b17.ply.gz',
#  './articulated/teddy\\teddyPly\\b18.ply.gz',
#  './articulated/teddy\\teddyPly\\b19.ply.gz',
#  './articulated/teddy\\teddyPly\\b2.ply.gz',
#  './articulated/teddy\\teddyPly\\b20.ply.gz',
#  './articulated/teddy\\teddyPly\\b3.ply.gz',
#  './articulated/teddy\\teddyPly\\b4.ply.gz',
#  './articulated/teddy\\teddyPly\\b5.ply.gz',
#  './articulated/teddy\\teddyPly\\b6.ply.gz',
#  './articulated/teddy\\teddyPly\\b7.ply.gz',
#  './articulated/teddy\\teddyPly\\b8.ply.gz',
#  './articulated/teddy\\teddyPly\\b9.ply.gz']

# %%
def generate2dImage(mesh,input_file_name,item): 
    # Assuming meshes is an array of Trimesh objects
    scene = mesh.scene()
    label = item['label']
    # Define your ranges for theta and phi

    number_of_rotation = 3
    theta = 2*np.pi/number_of_rotation

    for i in range(number_of_rotation):
        for j in range(number_of_rotation):
            # Rotation matrix around the Y-axis (theta)
            rotate_y = trimesh.transformations.rotation_matrix(
                angle=theta, direction=[0, 1, 0], point=scene.centroid)

            # Rotation matrix around the X-axis (phi)
            rotate_x = trimesh.transformations.rotation_matrix(
                angle=theta, direction=[1, 0, 0], point=scene.centroid)

            # Combine the rotations
            rotate_combined = trimesh.transformations.concatenate_matrices(rotate_x, rotate_y)
            # Apply the combined transform to the camera view transform
            camera_old, _geometry = scene.graph[scene.camera.name]
            camera_new = np.dot(rotate_combined, camera_old)
            scene.graph[scene.camera.name] = camera_new

            if not os.path.exists(f'2dImages\{label}\{input_file_name}'):
                os.makedirs(f'2dImages\{label}\{input_file_name}')

            # Save the rendered image
            try:
                # Increment the file name
                file_name = os.path.join(f'2dImages\{label}\{input_file_name}',f"{input_file_name}_{i}{j}.png")
                # Save a render of the object as a png
                png = scene.save_image(resolution=[256, 256])
                with open(file_name, "wb") as f:
                    f.write(png)
                    f.close()
            except BaseException as E:
                trimesh.constants.log.debug("Unable to save image", str(E))

# %%
generate2dImage(mcgill_dataset_ply.get_mesh(0),os.path.basename(mcgill_dataset_ply.all_data_paths[0]),mcgill_dataset_ply[0])

# %%
for i in range(len(mcgill_dataset_ply) - 1, -1, -1):
    # print(f"{i/len(mcgill_dataset_ply)*100}%")
    generate2dImage(mcgill_dataset_ply.get_mesh(i),os.path.basename(mcgill_dataset_ply.all_data_paths[i]),mcgill_dataset_ply[i])
